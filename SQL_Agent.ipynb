# %%
# !pip install openai langchain langchain-openai langchain-community mysql-connector-python sqlalchemy

# %%
import osimport warningswarnings.filterwarnings('ignore')from langchain_openai import ChatOpenAIfrom langchain.agents import AgentTypefrom langchain_community.utilities.sql_database import SQLDatabasefrom langchain_community.agent_toolkits import create_sql_agent# IMPORTANTE: Reemplaza 'sk-tu-api-key-aqui' con tu API Key real de OpenAIos.environ["OPENAI_API_KEY"] = "tu_api_key"print("✅ Configuración completada")

# %%
mysql_uri = 'mysql+mysqlconnector://root:mypassword123@localhost:3306/Chinook'try:    db = SQLDatabase.from_uri(mysql_uri)    print("✅ Conectado a MySQL")    print(f"\n📊 Tablas disponibles:")    for tabla in db.get_usable_table_names():        print(f"  • {tabla}")except Exception as e:    print(f"❌ Error: {e}")

# %%
llm = ChatOpenAI(model="gpt-4o-mini", temperature=0.2)agent = create_sql_agent(    llm=llm,     db=db,     verbose=True,     handle_parsing_errors=True,     agent_type=AgentType.ZERO_SHOT_REACT_DESCRIPTION)print("✅ Agente SQL creado exitosamente")

# %%
def preguntar(pregunta):    """Hacer preguntas a la base de datos en lenguaje natural"""    print(f"\n{'='*60}")    print(f"❓ PREGUNTA: {pregunta}")    print(f"{'='*60}\n")        try:        resultado = agent.invoke(pregunta)        print(f"\n{'='*60}")        print("✅ RESPUESTA:")        print(f"{'='*60}")        print(resultado['output'])        return resultado    except Exception as e:        print(f"❌ Error: {e}")        return None

# %%
preguntar("¿Cuántos álbumes hay en la base de datos?")

# %%
preguntar("¿Cuántos empleados hay?")

# %%
preguntar("¿Qué país tiene los clientes que más gastaron?")

# %%
preguntar("Muéstrame los 5 géneros musicales más vendidos")

# %%
preguntar("¿Cuál es el cliente que más dinero ha gastado?")
